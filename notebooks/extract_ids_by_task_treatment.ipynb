# %%
from pathlib import Path
import sys

repo_root = Path.cwd().resolve().parent
sys.path.append(str(repo_root))

# %%
from scripts.db_utils import get_filtered_pose_file
from scripts.dlc_io import load_dlc_dataframe
from scripts.motion_features import compute_velocity
from scripts.feature_summary import summarize_feature
